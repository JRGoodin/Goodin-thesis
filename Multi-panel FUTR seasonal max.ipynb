# %% [markdown]
# # Notebook for creating muti-panel seasonal climo figures using png images

# %% [markdown]
# ### Import necessary libaries (matplotlib for plotting, PIL Image for reading in and showing images)

# %%
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# ## Read in severe mid-FUTR (RCP 4.5, 8.5) and end-FUTR (RCP 4.5, 8.5) .png images from scratch directory and assign to variables

# %%
mid4p5_DJF_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/mid4p5_sev_DJF_max.png')
mid4p5_MAM_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/mid4p5_sev_MAM_max.png')
mid4p5_JJA_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/mid4p5_sev_JJA_max.png')
mid4p5_SON_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/mid4p5_sev_SON_max.png')

mid8p5_DJF_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/mid8p5_sev_DJF_max.png')
mid8p5_MAM_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/mid8p5_sev_MAM_max.png')
mid8p5_JJA_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/mid8p5_sev_JJA_max.png')
mid8p5_SON_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/mid8p5_sev_SON_max.png')

end4p5_DJF_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/end4p5_sev_DJF_max.png')
end4p5_MAM_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/end4p5_sev_MAM_max.png')
end4p5_JJA_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/end4p5_sev_JJA_max.png')
end4p5_SON_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/end4p5_sev_SON_max.png')

end8p5_DJF_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/end8p5_sev_DJF_max.png')
end8p5_MAM_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/end8p5_sev_MAM_max.png')
end8p5_JJA_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/end8p5_sev_JJA_max.png')
end8p5_SON_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/end8p5_sev_SON_max.png')

# %% [markdown]
# ## Use imshow to open images and create 4x4 subplot, assign each image to place 1-16

# %%
fig = plt.figure(figsize = (14, 10)) #Create a 10x10 figure
ax = plt.subplot()
plt.subplot(4, 4, 1) #Assign image to position 1 of 4x4 subplot
plt.imshow(mid4p5_DJF_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('a)', xy = (30., 90.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate first panel as "a"

plt.subplot(4, 4, 2) #Assign image to position 2 of 4x4 subplot
plt.imshow(mid8p5_DJF_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('b)', xy = (30., 90.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate second panel as "b"

plt.subplot(4, 4, 3) #Assign image to position 3 of 4x4 subplot
plt.imshow(end4p5_DJF_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('c)', xy = (30., 90.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate third panel as "c"

plt.subplot(4, 4, 4) #Assign image to position 4 of 4x4 subplot
plt.imshow(end8p5_DJF_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('d)', xy = (30., 90.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fourth panel as "d"

plt.subplot(4, 4, 5) #Assign image to position 5 of 4x4 subplot
plt.imshow(mid4p5_MAM_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('e)', xy = (30., 90.),fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fifth panel as "e"

plt.subplot(4, 4, 6) #Assign image to position 6 of 4x4 subplot
plt.imshow(mid8p5_MAM_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('f)', xy = (30., 90.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate sixth panel as "f"

plt.subplot(4, 4, 7) #Assign image to position 7 of 4x4 subplot
plt.imshow(end4p5_MAM_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('g)', xy = (30., 90.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate seventh panel as "g"

plt.subplot(4, 4, 8) #Assign image to position 8 of 4x4 subplot
plt.imshow(end8p5_MAM_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('h)', xy = (30., 90.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate eigth panel as "h"

plt.subplot(4, 4, 9) #Assign image to position 9 of 4x4 subplot
plt.imshow(mid4p5_JJA_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('i)', xy = (30., 90.),fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate ninth panel as "i"

plt.subplot(4, 4, 10) #Assign image to position 10 of 4x4 subplot
plt.imshow(mid8p5_JJA_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('j)', xy = (30., 90.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate tenth panel as "j"

plt.subplot(4, 4, 11) #Assign image to position 11 of 4x4 subplot
plt.imshow(end4p5_JJA_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('k)', xy = (30., 90.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate eleventh panel as "k"

plt.subplot(4, 4, 12) #Assign image to position 12 of 4x4 subplot
plt.imshow(end8p5_JJA_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('l)', xy = (30., 90.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate twelfth panel as "l"

plt.subplot(4, 4, 13) #Assign image to position 13 of 4x4 subplot
plt.imshow(mid4p5_SON_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('m)', xy = (30., 90.),fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate thirteenth panel as "m"

plt.subplot(4, 4, 14) #Assign image to position 14 of 4x4 subplot
plt.imshow(mid8p5_SON_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('n)', xy = (30., 90.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fourteenth panel as "n"

plt.subplot(4, 4, 15) #Assign image to position 15 of 4x4 subplot
plt.imshow(end4p5_SON_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('o)', xy = (30., 90.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fifteenth panel as "o"

plt.subplot(4, 4, 16) #Assign image to position 16 of 4x4 subplot
plt.imshow(end8p5_SON_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('p)', xy = (30., 90.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate sixteenth panel as "p"

plt.subplots_adjust(wspace=0, hspace=0)
fig.patch.set_edgecolor('black') #Outline figure with black line
fig.patch.set_linewidth('3.5') #Set linewidth of outline
#plt.tight_layout() #Automatically spaces panels out to match figure size

# %% [markdown]
# # Repeat for ≥ 4 cm

# %% [markdown]
# ## Read in severe mid-FUTR (RCP 4.5, 8.5) and end-FUTR (RCP 4.5, 8.5) .png images from scratch directory and assign to variables

# %%
mid4p5_DJF_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/mid4p5_4cm_DJF_max.png')
mid4p5_MAM_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/mid4p5_4cm_MAM_max.png')
mid4p5_JJA_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/mid4p5_4cm_JJA_max.png')
mid4p5_SON_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/mid4p5_4cm_SON_max.png')

mid8p5_DJF_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/mid8p5_4cm_DJF_max.png')
mid8p5_MAM_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/mid8p5_4cm_MAM_max.png')
mid8p5_JJA_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/mid8p5_4cm_JJA_max.png')
mid8p5_SON_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/mid8p5_4cm_SON_max.png')

end4p5_DJF_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/end4p5_4cm_DJF_max.png')
end4p5_MAM_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/end4p5_4cm_MAM_max.png')
end4p5_JJA_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/end4p5_4cm_JJA_max.png')
end4p5_SON_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/end4p5_4cm_SON_max.png')

end8p5_DJF_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/end8p5_4cm_DJF_max.png')
end8p5_MAM_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/end8p5_4cm_MAM_max.png')
end8p5_JJA_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/end8p5_4cm_JJA_max.png')
end8p5_SON_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/end8p5_4cm_SON_max.png')

# %% [markdown]
# ## Use imshow to open images and create 4x4 subplot, assign each image to place 1-16

# %%
fig = plt.figure(figsize = (14, 10)) #Create a 10x10 figure
ax = plt.subplot()
plt.subplot(4, 4, 1) #Assign image to position 1 of 4x4 subplot
plt.imshow(mid4p5_DJF_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('a)', xy = (0., 90.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate first panel as "a"

plt.subplot(4, 4, 2) #Assign image to position 2 of 4x4 subplot
plt.imshow(mid8p5_DJF_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('b)', xy = (0., 90.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate second panel as "b"

plt.subplot(4, 4, 3) #Assign image to position 3 of 4x4 subplot
plt.imshow(end4p5_DJF_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('c)', xy = (0., 90.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate third panel as "c"

plt.subplot(4, 4, 4) #Assign image to position 4 of 4x4 subplot
plt.imshow(end8p5_DJF_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('d)', xy = (0., 90.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fourth panel as "d"

plt.subplot(4, 4, 5) #Assign image to position 5 of 4x4 subplot
plt.imshow(mid4p5_MAM_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('e)', xy = (0., 90.),fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fifth panel as "e"

plt.subplot(4, 4, 6) #Assign image to position 6 of 4x4 subplot
plt.imshow(mid8p5_MAM_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('f)', xy = (0., 90.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate sixth panel as "f"

plt.subplot(4, 4, 7) #Assign image to position 7 of 4x4 subplot
plt.imshow(end4p5_MAM_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('g)', xy = (0., 90.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate seventh panel as "g"

plt.subplot(4, 4, 8) #Assign image to position 8 of 4x4 subplot
plt.imshow(end8p5_MAM_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('h)', xy = (0., 90.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate eigth panel as "h"

plt.subplot(4, 4, 9) #Assign image to position 9 of 4x4 subplot
plt.imshow(mid4p5_JJA_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('i)', xy = (0., 90.),fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate ninth panel as "i"

plt.subplot(4, 4, 10) #Assign image to position 10 of 4x4 subplot
plt.imshow(mid8p5_JJA_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('j)', xy = (0., 90.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate tenth panel as "j"

plt.subplot(4, 4, 11) #Assign image to position 11 of 4x4 subplot
plt.imshow(end4p5_JJA_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('k)', xy = (0., 90.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate eleventh panel as "k"

plt.subplot(4, 4, 12) #Assign image to position 12 of 4x4 subplot
plt.imshow(end8p5_JJA_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('l)', xy = (0., 90.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate twelfth panel as "l"

plt.subplot(4, 4, 13) #Assign image to position 13 of 4x4 subplot
plt.imshow(mid4p5_SON_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('m)', xy = (0., 90.),fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate thirteenth panel as "m"

plt.subplot(4, 4, 14) #Assign image to position 14 of 4x4 subplot
plt.imshow(mid8p5_SON_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('n)', xy = (0., 90.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fourteenth panel as "n"

plt.subplot(4, 4, 15) #Assign image to position 15 of 4x4 subplot
plt.imshow(end4p5_SON_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('o)', xy = (0., 90.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fifteenth panel as "o"

plt.subplot(4, 4, 16) #Assign image to position 16 of 4x4 subplot
plt.imshow(end8p5_SON_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('p)', xy = (0., 90.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate sixteenth panel as "p"

plt.subplots_adjust(wspace=0, hspace=0)
fig.patch.set_edgecolor('black') #Outline figure with black line
fig.patch.set_linewidth('3.5') #Set linewidth of outline
#plt.tight_layout() #Automatically spaces panels out to match figure size
