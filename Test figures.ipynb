# %%
import matplotlib.pyplot as plt
from PIL import Image

# %%
test = Image.open('/home/scratch/jgoodin/sev_hail_day_climos/HIST_end8p5_sev_hail_percentdiff_panel_USE_THIS.png')
#test2 = Image.open('/home/scratch/jgoodin/compare_wrf_mesh/use_these_figures/mean_annual_75km_gridded_sev_hail_report_days_ACTUAL.png')

# %%
fig = plt.figure(figsize = (16, 14)) #Create a 14x10 figure
plt.subplot(1, 2, 1) #Assign image to position 1 of 2x2 subplot
plt.imshow(test) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image

plt.subplot(1, 2, 2) #Assign image to position 2 of 2x2 subplot
plt.imshow(test2) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
plt.tight_layout()

# %%
fig = plt.figure(figsize = (12, 12))
plt.imshow(test)
plt.axis('off')
# Out:
# (-0.5, 1007.5, 719.5, -0.5)
