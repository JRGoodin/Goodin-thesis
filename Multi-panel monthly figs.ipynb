# %% [markdown]
# # Notebook for creating muti-panel monthly climo figures using png images

# %% [markdown]
# ### Import necessary libaries (matplotlib for plotting, PIL Image for reading in and showing images)

# %%
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# ## Read in min, mean, max, and stdev .png images from scratch directory and assign to variables

# %% [markdown]
# ### **Creating figure only for Jan-April first- open these figures first

# %%
Jan_min = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/mins/Jan_min.png')
Jan_mean = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/means/Jan_mean.png')
Jan_max = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/max/Jan_max.png')
Jan_stdev = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/stdev/Jan_stdev.png')
Feb_min = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/mins/Feb_min.png')
Feb_mean = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/means/Feb_mean.png')
Feb_max = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/max/Feb_max.png')
Feb_stdev = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/stdev/Feb_stdev.png')
March_min = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/mins/March_min.png')
March_mean = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/means/March_mean.png')
March_max = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/max/March_max.png')
March_stdev = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/stdev/March_stdev.png')
April_min = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/mins/April_min.png')
April_mean = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/means/April_mean.png')
April_max = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/max/April_max.png')
April_stdev = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/stdev/April_stdev.png')

# %% [markdown]
# ## Use imshow to open images and create 4x4 subplot, assign each image to place 1-16

# %%
fig = plt.figure(figsize = (14, 10)) #Create a 10x10 figure
ax = plt.subplot()
plt.subplot(4, 4, 1) #Assign image to position 1 of 4x4 subplot
plt.imshow(Jan_min) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('a)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate first panel as "a"

plt.subplot(4, 4, 2) #Assign image to position 2 of 4x4 subplot
plt.imshow(Jan_mean) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('b)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate second panel as "b"

plt.subplot(4, 4, 3) #Assign image to position 3 of 4x4 subplot
plt.imshow(Jan_max) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('c)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate third panel as "c"

plt.subplot(4, 4, 4) #Assign image to position 4 of 4x4 subplot
plt.imshow(Jan_stdev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('d)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fourth panel as "d"

plt.subplot(4, 4, 5) #Assign image to position 5 of 4x4 subplot
plt.imshow(Feb_min) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('e)', xy = (75., 100.),fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fifth panel as "e"

plt.subplot(4, 4, 6) #Assign image to position 6 of 4x4 subplot
plt.imshow(Feb_mean) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('f)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate sixth panel as "f"

plt.subplot(4, 4, 7) #Assign image to position 7 of 4x4 subplot
plt.imshow(Feb_max) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('g)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate seventh panel as "g"

plt.subplot(4, 4, 8) #Assign image to position 8 of 4x4 subplot
plt.imshow(Feb_stdev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('h)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate eigth panel as "h"

plt.subplot(4, 4, 9) #Assign image to position 9 of 4x4 subplot
plt.imshow(March_min) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('i)', xy = (75., 100.),fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate ninth panel as "i"

plt.subplot(4, 4, 10) #Assign image to position 10 of 4x4 subplot
plt.imshow(March_mean) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('j)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate tenth panel as "j"

plt.subplot(4, 4, 11) #Assign image to position 11 of 4x4 subplot
plt.imshow(March_max) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('k)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate eleventh panel as "k"

plt.subplot(4, 4, 12) #Assign image to position 12 of 4x4 subplot
plt.imshow(March_stdev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('l)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate twelfth panel as "l"

plt.subplot(4, 4, 13) #Assign image to position 13 of 4x4 subplot
plt.imshow(April_min) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('m)', xy = (75., 100.),fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate thirteenth panel as "m"

plt.subplot(4, 4, 14) #Assign image to position 14 of 4x4 subplot
plt.imshow(April_mean) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('n)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fourteenth panel as "n"

plt.subplot(4, 4, 15) #Assign image to position 15 of 4x4 subplot
plt.imshow(April_max) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('o)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fifteenth panel as "o"

plt.subplot(4, 4, 16) #Assign image to position 16 of 4x4 subplot
plt.imshow(April_stdev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('p)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate sixteenth panel as "p"

plt.subplots_adjust(wspace=0, hspace=0)
fig.patch.set_edgecolor('black') #Outline figure with black line
fig.patch.set_linewidth('3.5') #Set linewidth of outline
#plt.tight_layout() #Automatically spaces panels out to match figure size

# %% [markdown]
# ## Repeat same process as above with May-August images

# %%
May_min = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/mins/May_min.png')
May_mean = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/means/May_mean.png')
May_max = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/max/May_max.png')
May_stdev = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/stdev/May_stdev.png')
June_min = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/mins/June_min.png')
June_mean = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/means/June_mean.png')
June_max = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/max/June_max.png')
June_stdev = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/stdev/June_stdev.png')
July_min = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/mins/July_min.png')
July_mean = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/means/July_mean.png')
July_max = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/max/July_max.png')
July_stdev = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/stdev/July_stdev.png')
August_min = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/mins/August_min.png')
August_mean = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/means/August_mean.png')
August_max = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/max/August_max.png')
August_stdev = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/stdev/August_stdev.png')

# %% [markdown]
# ### Create 16-panel figure for May-August

# %%
fig = plt.figure(figsize = (14, 10)) #Create a 10x10 figure
ax = plt.subplot()
plt.subplot(4, 4, 1) #Assign image to position 1 of 4x4 subplot
plt.imshow(May_min) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('a)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate first panel as "a"

plt.subplot(4, 4, 2) #Assign image to position 2 of 4x4 subplot
plt.imshow(May_mean) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('b)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate second panel as "b"

plt.subplot(4, 4, 3) #Assign image to position 3 of 4x4 subplot
plt.imshow(May_max) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('c)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate third panel as "c"

plt.subplot(4, 4, 4) #Assign image to position 4 of 4x4 subplot
plt.imshow(May_stdev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('d)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fourth panel as "d"

plt.subplot(4, 4, 5) #Assign image to position 5 of 4x4 subplot
plt.imshow(June_min) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('e)', xy = (75., 100.),fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fifth panel as "e"

plt.subplot(4, 4, 6) #Assign image to position 6 of 4x4 subplot
plt.imshow(June_mean) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('f)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate sixth panel as "f"

plt.subplot(4, 4, 7) #Assign image to position 7 of 4x4 subplot
plt.imshow(June_max) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('g)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate seventh panel as "g"

plt.subplot(4, 4, 8) #Assign image to position 8 of 4x4 subplot
plt.imshow(June_stdev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('h)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate eigth panel as "h"

plt.subplot(4, 4, 9) #Assign image to position 9 of 4x4 subplot
plt.imshow(July_min) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('i)', xy = (75., 100.),fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate ninth panel as "i"

plt.subplot(4, 4, 10) #Assign image to position 10 of 4x4 subplot
plt.imshow(July_mean) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('j)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate tenth panel as "j"

plt.subplot(4, 4, 11) #Assign image to position 11 of 4x4 subplot
plt.imshow(July_max) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('k)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate eleventh panel as "k"

plt.subplot(4, 4, 12) #Assign image to position 12 of 4x4 subplot
plt.imshow(July_stdev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('l)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate twelfth panel as "l"

plt.subplot(4, 4, 13) #Assign image to position 13 of 4x4 subplot
plt.imshow(August_min) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('m)', xy = (75., 100.),fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate thirteenth panel as "m"

plt.subplot(4, 4, 14) #Assign image to position 14 of 4x4 subplot
plt.imshow(August_mean) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('n)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fourteenth panel as "n"

plt.subplot(4, 4, 15) #Assign image to position 15 of 4x4 subplot
plt.imshow(August_max) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('o)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fifteenth panel as "o"

plt.subplot(4, 4, 16) #Assign image to position 16 of 4x4 subplot
plt.imshow(August_stdev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('p)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate sixteenth panel as "p"

plt.subplots_adjust(wspace=0, hspace=0)
fig.patch.set_edgecolor('black') #Outline figure with black line
fig.patch.set_linewidth('3.5') #Set linewidth of outline
#plt.tight_layout() #Automatically spaces panels out to match figure size

# %% [markdown]
# ## Repeat above process for Sep-Dec

# %%
Sep_min = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/mins/Sep_min.png')
Sep_mean = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/means/Sep_mean.png')
Sep_max = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/max/Sep_max.png')
Sep_stdev = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/stdev/Sep_stdev.png')
Oct_min = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/mins/Oct_min.png')
Oct_mean = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/means/Oct_mean.png')
Oct_max = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/max/Oct_max.png')
Oct_stdev = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/stdev/Oct_stdev.png')
Nov_min = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/mins/Nov_min.png')
Nov_mean = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/means/Nov_mean.png')
Nov_max = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/max/Nov_max.png')
Nov_stdev = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/stdev/Nov_stdev.png')
Dec_min = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/mins/Dec_min.png')
Dec_mean = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/means/Dec_mean.png')
Dec_max = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/max/Dec_max.png')
Dec_stdev = Image.open('/home/scratch/jgoodin/monthly_mesh_climos/stdev/Dec_stdev.png')

# %% [markdown]
# ### Create 16-panel figure for Sep-Dec

# %%
fig = plt.figure(figsize = (14, 10)) #Create a 10x10 figure
ax = plt.subplot()
plt.subplot(4, 4, 1) #Assign image to position 1 of 4x4 subplot
plt.imshow(Sep_min) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('a)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate first panel as "a"

plt.subplot(4, 4, 2) #Assign image to position 2 of 4x4 subplot
plt.imshow(Sep_mean) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('b)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate second panel as "b"

plt.subplot(4, 4, 3) #Assign image to position 3 of 4x4 subplot
plt.imshow(Sep_max) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('c)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate third panel as "c"

plt.subplot(4, 4, 4) #Assign image to position 4 of 4x4 subplot
plt.imshow(Sep_stdev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('d)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fourth panel as "d"

plt.subplot(4, 4, 5) #Assign image to position 5 of 4x4 subplot
plt.imshow(Oct_min) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('e)', xy = (75., 100.),fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fifth panel as "e"

plt.subplot(4, 4, 6) #Assign image to position 6 of 4x4 subplot
plt.imshow(Oct_mean) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('f)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate sixth panel as "f"

plt.subplot(4, 4, 7) #Assign image to position 7 of 4x4 subplot
plt.imshow(Oct_max) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('g)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate seventh panel as "g"

plt.subplot(4, 4, 8) #Assign image to position 8 of 4x4 subplot
plt.imshow(Oct_stdev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('h)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate eigth panel as "h"

plt.subplot(4, 4, 9) #Assign image to position 9 of 4x4 subplot
plt.imshow(Nov_min) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('i)', xy = (75., 100.),fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate ninth panel as "i"

plt.subplot(4, 4, 10) #Assign image to position 10 of 4x4 subplot
plt.imshow(Nov_mean) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('j)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate tenth panel as "j"

plt.subplot(4, 4, 11) #Assign image to position 11 of 4x4 subplot
plt.imshow(Nov_max) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('k)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate eleventh panel as "k"

plt.subplot(4, 4, 12) #Assign image to position 12 of 4x4 subplot
plt.imshow(Nov_stdev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('l)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate twelfth panel as "l"

plt.subplot(4, 4, 13) #Assign image to position 13 of 4x4 subplot
plt.imshow(Dec_min) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('m)', xy = (75., 100.),fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate thirteenth panel as "m"

plt.subplot(4, 4, 14) #Assign image to position 14 of 4x4 subplot
plt.imshow(Dec_mean) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('n)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fourteenth panel as "n"

plt.subplot(4, 4, 15) #Assign image to position 15 of 4x4 subplot
plt.imshow(Dec_max) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('o)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fifteenth panel as "o"

plt.subplot(4, 4, 16) #Assign image to position 16 of 4x4 subplot
plt.imshow(Dec_stdev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('p)', xy = (75., 100.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate sixteenth panel as "p"

plt.subplots_adjust(wspace=0, hspace=0)
fig.patch.set_edgecolor('black') #Outline figure with black line
fig.patch.set_linewidth('3.5') #Set linewidth of outline
#plt.tight_layout() #Automatically spaces panels out to match figure size
