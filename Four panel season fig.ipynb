# %% [markdown]
# # Notebook for creating a four panel figure using png images

# %% [markdown]
# ### Import necessary libaries (matplotlib for plotting, PIL Image for reading in and showing images)

# %%
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# ## Read in .png images containing seasonal max ≥ 1 in [2.54 cm] and ≥ 1.57 in [4 cm] from scratch directory and assign to variables

# %%
DJF = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/DJF_4cm_max_panel_fig.png') #Read in DJF max .png file from seasonal mesh directory
MAM = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/MAM_4cm_max_panel_fig.png') #Read in MAM max .png file from seasonal mesh directory
JJA = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/JJA_4cm_max_panel_fig.png') #Read in JJA max .png file from seasonal mesh directory
SON = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/max/SON_4cm_max_panel_fig.png') #Read in SON max .png file from seasonal mesh directory

# %% [markdown]
# ## Use imshow to open images and create 2x2 subplot, assign each image to place 1-4

# %%
fig = plt.figure(figsize = (12, 8)) #Create a 12x8 figure
plt.subplot(2, 2, 1) #Assign image to position 1 of 2x2 subplot
plt.imshow(DJF) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('a)', xy = (20., 70.), fontsize = 26, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate first panel as "a"

plt.subplot(2, 2, 2) #Assign image to position 2 of 2x2 subplot
plt.imshow(MAM) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('b)', xy = (0., 70.), fontsize = 26, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate second panel as "b"

plt.subplot(2, 2, 3) #Assign image to position 3 of 2x2 subplot
plt.imshow(JJA) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('c)', xy = (20., 70.), fontsize = 26, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate third panel as "c"

plt.subplot(2, 2, 4) #Assign image to position 4 of 2x2 subplot
plt.imshow(SON) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('d)', xy = (0., 70.), fontsize = 26, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fourth panel as "d"

#plt.subplots_adjust(wspace=0, hspace=0)
fig.patch.set_edgecolor('black') #Outline figure with black line
fig.patch.set_linewidth('3.5') #Set linewidth of outline
plt.tight_layout() #Automatically spaces panels out to match figure size

plt.savefig('/home/scratch/jgoodin/seasonal_mesh_climos/max/four_panel_seasonal_max_4cm.png') #Save figure as .png to scratch directory
