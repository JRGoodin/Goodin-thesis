# %%
import numpy as np
import netCDF4 as nc
from netCDF4 import Dataset
import matplotlib.pyplot as plt
import xarray as xr
import matplotlib.gridspec as gridspec
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.io.shapereader as shpreader
import xarray as xr
from PIL import Image

# %%
DJF = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/DJF_max.png')
MAM = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/MAM_max.png')
JJA = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/JJA_max.png')
SON = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/SON_max.png')

# %%
fig = plt.figure(figsize = (14, 10))
plt.subplot(2, 2, 1)
plt.imshow(DJF)
plt.axis('off')
plt.title('DJF', fontsize = 18)

plt.subplot(2, 2, 2)
plt.imshow(MAM)
plt.axis('off')
plt.title('MAM', fontsize = 18)

plt.subplot(2, 2, 3)
plt.imshow(JJA)
plt.axis('off')
plt.title('JJA', fontsize = 18)

plt.subplot(2, 2, 4)
plt.imshow(SON)
plt.axis('off')
plt.title('SON', fontsize = 18)
plt.tight_layout()
#plt.subplots_adjust(wspace = 0., hspace = 0.)
