# %% [markdown]
# # Notebook for creating a muti-panel seasonal delta climo figure using png images

# %% [markdown]
# ### Import necessary libaries (matplotlib for plotting, PIL Image for reading in and showing images)

# %%
import matplotlib.pyplot as plt
from PIL import Image
import cartopy.crs as ccrs

# %% [markdown]
# ## Read in severe mid-FUTR (RCP 4.5, 8.5) and end-FUTR (RCP 4.5, 8.5) .png images from scratch directory and assign to variables

# %%
delta_mid4p5_DJF_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_mid_4p5_DJF_4cm_final.png')
delta_mid8p5_DJF_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_mid_8p5_DJF_4cm_final.png')
delta_end4p5_DJF_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_end_4p5_DJF_4cm_final.png')
delta_end8p5_DJF_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_end_8p5_DJF_4cm_final.png')

delta_mid4p5_MAM_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_mid_4p5_MAM_4cm_final.png')
delta_mid8p5_MAM_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_mid_8p5_MAM_4cm_final.png')
delta_end4p5_MAM_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_end_4p5_MAM_4cm_final.png')
delta_end8p5_MAM_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_end_8p5_MAM_4cm_final.png')

delta_mid4p5_JJA_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_mid_4p5_JJA_4cm_final.png')
delta_mid8p5_JJA_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_mid_8p5_JJA_4cm_final.png')
delta_end4p5_JJA_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_end_4p5_JJA_4cm_final.png')
delta_end8p5_JJA_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_end_8p5_JJA_4cm_final.png')

delta_mid4p5_SON_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_mid_4p5_SON_4cm_final.png')
delta_mid8p5_SON_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_mid_8p5_SON_4cm_final.png')
delta_end4p5_SON_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_end_4p5_SON_4cm_final.png')
delta_end8p5_SON_sev = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_end_8p5_SON_4cm_final.png')

# %% [markdown]
# ## Use imshow to open images and create 4x4 subplot, assign each image to place 1-16

# %%
import matplotlib.gridspec as gridspec
fig = plt.figure(figsize = (22, 16)) #Create a figure
#fig, axs = gridspec.GridSpec(4, 4, width_ratios = [2, 2, 2, 2], height_ratios = [2, 2, 2, 2])
#ax = plt.subplot()
#rows, cols = 4, 4
#fig, axs = gridspec.GridSpec(rows, cols, wspace=0.05, hspace=0.05)

#ax.text(0.5, 0.5, 'DJF', fontsize=40, rotation='vertical', transform=plt.gcf().transFigure, zorder = 10)
#ax.text(2, 6, 'MAM', fontsize=15, va='bottom', ha='center', rotation='vertical')
#ax.text(2, 6, 'JJA', fontsize=15, va='bottom', ha='center', rotation='vertical')
#ax.text(2, 6, 'SON', fontsize=15, va='bottom', ha='center', rotation='vertical')

plt.subplot(4, 4, 1) #Assign image to position 1 of 4x4 subplot
plt.imshow(delta_mid4p5_DJF_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('a)', xy = (10., 100.), fontsize = 24, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate first panel as "a"
ann = plt.annotate('DJF', xy = (20., 450.), fontsize = 36, rotation='vertical')

plt.subplot(4, 4, 2) #Assign image to position 2 of 4x4 subplot
plt.imshow(delta_mid8p5_DJF_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('b)', xy = (10., 100.), fontsize = 24, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate second panel as "b"

plt.subplot(4, 4, 3) #Assign image to position 3 of 4x4 subplot
plt.imshow(delta_end4p5_DJF_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('c)', xy = (10., 100.), fontsize = 24, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate third panel as "c"

plt.subplot(4, 4, 4) #Assign image to position 4 of 4x4 subplot
plt.imshow(delta_end8p5_DJF_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('d)', xy = (10., 100.), fontsize = 24, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fourth panel as "d"

plt.subplot(4, 4, 5) #Assign image to position 5 of 4x4 subplot
plt.imshow(delta_mid4p5_MAM_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('e)', xy = (10., 100.),fontsize = 24, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fifth panel as "e"
ann = plt.annotate('MAM', xy = (20., 475.), fontsize = 36, rotation='vertical')

plt.subplot(4, 4, 6) #Assign image to position 6 of 4x4 subplot
plt.imshow(delta_mid8p5_MAM_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('f)', xy = (10., 100.), fontsize = 24, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate sixth panel as "f"

plt.subplot(4, 4, 7) #Assign image to position 7 of 4x4 subplot
plt.imshow(delta_end4p5_MAM_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('g)', xy = (10., 100.), fontsize = 24, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate seventh panel as "g"

plt.subplot(4, 4, 8) #Assign image to position 8 of 4x4 subplot
plt.imshow(delta_end8p5_MAM_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('h)', xy = (10., 100.), fontsize = 24, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate eigth panel as "h"

plt.subplot(4, 4, 9) #Assign image to position 9 of 4x4 subplot
plt.imshow(delta_mid4p5_JJA_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('i)', xy = (10., 100.),fontsize = 24, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate ninth panel as "i"
ann = plt.annotate('JJA', xy = (20., 450.), fontsize = 36, rotation='vertical')

plt.subplot(4, 4, 10) #Assign image to position 10 of 4x4 subplot
plt.imshow(delta_mid8p5_JJA_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('j)', xy = (10., 100.), fontsize = 24, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate tenth panel as "j"

plt.subplot(4, 4, 11) #Assign image to position 11 of 4x4 subplot
plt.imshow(delta_end4p5_JJA_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('k)', xy = (10., 100.), fontsize = 24, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate eleventh panel as "k"

plt.subplot(4, 4, 12) #Assign image to position 12 of 4x4 subplot
plt.imshow(delta_end8p5_JJA_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('l)', xy = (10., 100.), fontsize = 24, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate twelfth panel as "l"

plt.subplot(4, 4, 13) #Assign image to position 13 of 4x4 subplot
plt.imshow(delta_mid4p5_SON_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('m)', xy = (10., 90.),fontsize = 24, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate thirteenth panel as "m"
ann = plt.annotate('SON', xy = (20., 475.), fontsize = 36, rotation='vertical')

plt.subplot(4, 4, 14) #Assign image to position 14 of 4x4 subplot
plt.imshow(delta_mid8p5_SON_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('n)', xy = (10., 90.), fontsize = 24, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fourteenth panel as "n"

plt.subplot(4, 4, 15) #Assign image to position 15 of 4x4 subplot
plt.imshow(delta_end4p5_SON_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('o)', xy = (10., 90.), fontsize = 24, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fifteenth panel as "o"

plt.subplot(4, 4, 16) #Assign image to position 16 of 4x4 subplot
plt.imshow(delta_end8p5_SON_sev) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('p)', xy = (10., 90.), fontsize = 24, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate sixteenth panel as "p"

#plt.subplots_adjust(wspace=None, hspace=None)
fig.patch.set_edgecolor('black') #Outline figure with black line
fig.patch.set_linewidth('3.5') #Set linewidth of outline
plt.tight_layout(pad = 0) #Automatically spaces panels out to match figure size

# %% [markdown]
# # Repeat for HAIL_MAX2D ≥ 4 cm

# %% [markdown]
# ## Read in ≥ 4 cm mid-FUTR (RCP 4.5, 8.5) and end-FUTR (RCP 4.5, 8.5) .png images from scratch directory and assign to variables

# %%
delta_mid4p5_DJF_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_mid_4p5_DJF_4cm.png')
delta_mid4p5_MAM_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_mid_4p5_MAM_4cm.png')
delta_mid4p5_JJA_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_mid_4p5_JJA_4cm.png')
delta_mid4p5_SON_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_mid_4p5_SON_4cm.png')

delta_mid8p5_DJF_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_mid_8p5_DJF_4cm.png')
delta_mid8p5_MAM_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_mid_8p5_MAM_4cm.png')
delta_mid8p5_JJA_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_mid_8p5_JJA_4cm.png')
delta_mid8p5_SON_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_mid_8p5_SON_4cm.png')

delta_end4p5_DJF_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_end_4p5_DJF_4cm.png')
delta_end4p5_MAM_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_end_4p5_MAM_4cm.png')
delta_end4p5_JJA_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_end_4p5_JJA_4cm.png')
delta_end4p5_SON_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_end_4p5_SON_4cm.png')

delta_end8p5_DJF_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_end_8p5_DJF_4cm.png')
delta_end8p5_MAM_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_end_8p5_MAM_4cm.png')
delta_end8p5_JJA_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_end_8p5_JJA_4cm.png')
delta_end8p5_SON_4cm = Image.open('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_end_8p5_SON_4cm.png')

# %% [markdown]
# ## Use imshow to open images and create 4x4 subplot, assign each image to place 1-16

# %%
fig = plt.figure(figsize = (14, 10)) #Create a 10x10 figure
ax = plt.subplot()
plt.subplot(4, 4, 1) #Assign image to position 1 of 4x4 subplot
plt.imshow(delta_mid4p5_DJF_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('a)', xy = (0., 160.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate first panel as "a"

plt.subplot(4, 4, 2) #Assign image to position 2 of 4x4 subplot
plt.imshow(delta_mid8p5_DJF_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('b)', xy = (0., 160.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate second panel as "b"

plt.subplot(4, 4, 3) #Assign image to position 3 of 4x4 subplot
plt.imshow(delta_end4p5_DJF_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('c)', xy = (0., 160.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate third panel as "c"

plt.subplot(4, 4, 4) #Assign image to position 4 of 4x4 subplot
plt.imshow(delta_end8p5_DJF_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('d)', xy = (0., 160.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fourth panel as "d"

plt.subplot(4, 4, 5) #Assign image to position 5 of 4x4 subplot
plt.imshow(delta_mid4p5_MAM_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('e)', xy = (0., 160.),fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fifth panel as "e"

plt.subplot(4, 4, 6) #Assign image to position 6 of 4x4 subplot
plt.imshow(delta_mid8p5_MAM_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('f)', xy = (0., 155.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate sixth panel as "f"

plt.subplot(4, 4, 7) #Assign image to position 7 of 4x4 subplot
plt.imshow(delta_end4p5_MAM_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('g)', xy = (0., 160.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate seventh panel as "g"

plt.subplot(4, 4, 8) #Assign image to position 8 of 4x4 subplot
plt.imshow(delta_end8p5_MAM_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('h)', xy = (0., 160.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate eigth panel as "h"

plt.subplot(4, 4, 9) #Assign image to position 9 of 4x4 subplot
plt.imshow(delta_mid4p5_JJA_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('i)', xy = (0., 160.),fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate ninth panel as "i"

plt.subplot(4, 4, 10) #Assign image to position 10 of 4x4 subplot
plt.imshow(delta_mid8p5_JJA_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('j)', xy = (0., 160.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate tenth panel as "j"

plt.subplot(4, 4, 11) #Assign image to position 11 of 4x4 subplot
plt.imshow(delta_end4p5_JJA_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('k)', xy = (0., 160.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate eleventh panel as "k"

plt.subplot(4, 4, 12) #Assign image to position 12 of 4x4 subplot
plt.imshow(delta_end8p5_JJA_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('l)', xy = (0., 160.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate twelfth panel as "l"

plt.subplot(4, 4, 13) #Assign image to position 13 of 4x4 subplot
plt.imshow(delta_mid4p5_SON_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib- we just want the image
ann = plt.annotate('m)', xy = (0., 160.),fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate thirteenth panel as "m"

plt.subplot(4, 4, 14) #Assign image to position 14 of 4x4 subplot
plt.imshow(delta_mid8p5_SON_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann1 = plt.annotate('n)', xy = (0., 160.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fourteenth panel as "n"

plt.subplot(4, 4, 15) #Assign image to position 15 of 4x4 subplot
plt.imshow(delta_end4p5_SON_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann2 = plt.annotate('o)', xy = (0., 160.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate fifteenth panel as "o"

plt.subplot(4, 4, 16) #Assign image to position 16 of 4x4 subplot
plt.imshow(delta_end8p5_SON_4cm) #Display image (contained in variable listed above)
plt.axis('off') #Remove axis automatically included by maptlotlib
ann3 = plt.annotate('p)', xy = (0., 160.), fontsize = 15, bbox=dict(boxstyle="round,pad=0.3", fc = 'lightblue')) #Annotate sixteenth panel as "p"

plt.subplots_adjust(wspace=0, hspace=0)
fig.patch.set_edgecolor('black') #Outline figure with black line
fig.patch.set_linewidth('3.5') #Set linewidth of outline
#plt.tight_layout() #Automatically spaces panels out to match figure size
