# %% [markdown]
# # Notebook for plotting seasonal delta HAIL_MAX2D for HIST, mid-FUTR (RCP 4.5, 8.5), and end-FUTR (RCP 4.5, 8.5)

# %% [markdown]
# ### Import necessary libraries

# %%
import numpy as np
import netCDF4 as nc
from netCDF4 import Dataset
import matplotlib.pyplot as plt
import xarray as xr
import matplotlib.gridspec as gridspec
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.io.shapereader as shpreader

# %% [markdown]
# ## Read in HIST max .nc files for DJF, MAM, JJA, and SON (saved to seasonal_mesh_climos/HIST in scratch directory)

# %%
hist_DJF_max = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/HIST/DJF_max_results.nc')
hist_MAM_max = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/HIST/MAM_max_results.nc')
hist_JJA_max = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/HIST/JJA_max_results.nc')
hist_SON_max = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/HIST/SON_max_results.nc')

# %% [markdown]
# ## Select HAIL_MAX2D variable to create plottable data array

# %%
hist_DJF_max = hist_DJF_max.HAIL_MAX2D
hist_MAM_max = hist_MAM_max.HAIL_MAX2D
hist_JJA_max = hist_JJA_max.HAIL_MAX2D
hist_SON_max = hist_SON_max.HAIL_MAX2D

# %% [markdown]
# ## Read in seasonal max files for mid, end-FUTR RCP 4.5, 8.5 (saved to seasonal_resamples in scratch directory)

# %%
mid_4p5_seasonal_max = xr.open_dataset('/home/scratch/jgoodin/seasonal_resamples/mid-century_4p5_seasonal_max_resample.nc')
mid_8p5_seasonal_max = xr.open_dataset('/home/scratch/jgoodin/seasonal_resamples/mid-century_8p5_seasonal_max_resample.nc')
end_4p5_seasonal_max = xr.open_dataset('/home/scratch/jgoodin/seasonal_resamples/end-century_4p5_seasonal_max_resample.nc')
end_8p5_seasonal_max = xr.open_dataset('/home/scratch/jgoodin/seasonal_resamples/end-century_8p5_seasonal_max_resample.nc')

# %% [markdown]
# ## Select by season for each FUTR file and save results to netcdf

# %% [markdown]
# ### Select by season for mid-FUTR RCP 4.5

# %%
#mid4p5_SON_max = mid_4p5_seasonal_max.sel(season = 'SON').HAIL_MAX2D

# %% [markdown]
# ### Save results to netcdf (saved to seasonal_mesh_climos/mid-FUTR directory in scratch)

# %%
#mid4p5_SON_max.to_netcdf('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid4p5_SON_seasonal_max.nc')

# %% [markdown]
# ## Repeat process for mid-FUTR RCP 8.5

# %%
#mid8p5_SON_max = mid_8p5_seasonal_max.sel(season = 'SON').HAIL_MAX2D

# %% [markdown]
# ### Save results to netcdf (saved to seasonal_mesh_climos/mid-FUTR directory in scratch)

# %%
#mid8p5_SON_max.to_netcdf('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid8p5_SON_seasonal_max.nc')

# %% [markdown]
# ## Repeat for end-FUTR RCP 4.5

# %%
#end4p5_SON_max = end_4p5_seasonal_max.sel(season = 'SON').HAIL_MAX2D

# %% [markdown]
# ### Save results to netcdf (saved to seasonal_mesh_climos/end-FUTR directory in scratch)

# %%
#end4p5_SON_max.to_netcdf('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end4p5_SON_seasonal_max.nc')

# %% [markdown]
# ## Repeat for end-FUTR RCP 8.5

# %%
#end8p5_SON_max = end_8p5_seasonal_max.sel(season = 'SON').HAIL_MAX2D

# %% [markdown]
# ### Save results to netcdf (saved to seasonal_mesh_climos/end-FUTR directory in scratch)

# %%
#end8p5_SON_max.to_netcdf('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end8p5_SON_seasonal_max.nc')

# %% [markdown]
# ## Assign each seasonal max file created above to a variable (DJF, MAM, JJA, SON)

# %%
mid_4p5_DJF = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid4p5_DJF_seasonal_max.nc')
mid_4p5_MAM = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid4p5_MAM_seasonal_max.nc')
mid_4p5_JJA = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid4p5_JJA_seasonal_max.nc')
mid_4p5_SON = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid4p5_SON_seasonal_max.nc')

#Repeat for mid-FUTR RCP 8.5

mid_8p5_DJF = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid8p5_DJF_seasonal_max.nc')
mid_8p5_MAM = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid8p5_MAM_seasonal_max.nc')
mid_8p5_JJA = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid8p5_JJA_seasonal_max.nc')
mid_8p5_SON = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid8p5_SON_seasonal_max.nc')

# %% [markdown]
# ### Repeat for end-FUTR

# %%
end_4p5_DJF = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end4p5_DJF_seasonal_max.nc')
end_4p5_MAM = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end4p5_MAM_seasonal_max.nc')
end_4p5_JJA = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end4p5_JJA_seasonal_max.nc')
end_4p5_SON = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end4p5_SON_seasonal_max.nc')

#Repeat for end-FUTR RCP 8.5

end_8p5_DJF = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end8p5_DJF_seasonal_max.nc')
end_8p5_MAM = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end8p5_MAM_seasonal_max.nc')
end_8p5_JJA = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end8p5_JJA_seasonal_max.nc')
end_8p5_SON = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end8p5_SON_seasonal_max.nc')

# %% [markdown]
# ## Select values of HAIL_MAX2D to create a plottable data array

# %%
mid_4p5_DJF = mid_4p5_DJF.HAIL_MAX2D
mid_4p5_MAM = mid_4p5_MAM.HAIL_MAX2D
mid_4p5_JJA = mid_4p5_JJA.HAIL_MAX2D
mid_4p5_SON = mid_4p5_SON.HAIL_MAX2D

mid_8p5_DJF = mid_8p5_DJF.HAIL_MAX2D
mid_8p5_MAM = mid_8p5_MAM.HAIL_MAX2D
mid_8p5_JJA = mid_8p5_JJA.HAIL_MAX2D
mid_8p5_SON = mid_8p5_SON.HAIL_MAX2D

#Repeat for end-FUTR

end_4p5_DJF = end_4p5_DJF.HAIL_MAX2D
end_4p5_MAM = end_4p5_MAM.HAIL_MAX2D
end_4p5_JJA = end_4p5_JJA.HAIL_MAX2D
end_4p5_SON = end_4p5_SON.HAIL_MAX2D

end_8p5_DJF = end_8p5_DJF.HAIL_MAX2D
end_8p5_MAM = end_8p5_MAM.HAIL_MAX2D
end_8p5_JJA = end_8p5_JJA.HAIL_MAX2D
end_8p5_SON = end_8p5_SON.HAIL_MAX2D

# %% [markdown]
# # Find deltas by subtracting HIST from FUTR (start with delta hist mid-FUTR RCP 4.5, 8.5)

# %%
delta_mid4p5_DJF = mid_4p5_DJF - hist_DJF_max
delta_mid4p5_MAM = mid_4p5_MAM - hist_MAM_max 
delta_mid4p5_JJA = mid_4p5_JJA - hist_JJA_max 
delta_mid4p5_SON = mid_4p5_SON - hist_SON_max 

#Repeat for mid-FUTR RCP 8.5                  # **These are plotting variables**

delta_mid8p5_DJF = mid_8p5_DJF - hist_DJF_max
delta_mid8p5_MAM = mid_8p5_MAM - hist_MAM_max 
delta_mid8p5_JJA = mid_8p5_JJA - hist_JJA_max 
delta_mid8p5_SON = mid_8p5_SON - hist_SON_max

# %% [markdown]
# # Find deltas for end-FUTR RCP 4.5, 8.5

# %%
delta_end4p5_DJF = end_4p5_DJF - hist_DJF_max 
delta_end4p5_MAM = end_4p5_MAM - hist_MAM_max 
delta_end4p5_JJA = end_4p5_JJA - hist_JJA_max 
delta_end4p5_SON = end_4p5_SON - hist_SON_max 

#Repeat for mid-FUTR RCP 8.5                   # **These are plotting variables**

delta_end8p5_DJF = end_8p5_DJF - hist_DJF_max 
delta_end8p5_MAM = end_8p5_MAM - hist_MAM_max 
delta_end8p5_JJA = end_8p5_JJA - hist_JJA_max 
delta_end8p5_SON = end_8p5_SON - hist_SON_max

# %% [markdown]
# ### Import netcdf file containing lat/lon coords for WRF files

# %%
coords = xr.open_dataset('lat_lon.nc') #Open .nc file containing WRF lat/lon coords

# %% [markdown]
# ### Assign lat/lon coords from file to variables

# %%
lats = coords.CLAT.values[0, :, :]
lons = coords.CLONG.values[0, :, :]

# %% [markdown]
# ## Plot deltas on map of CONUS

# %%
fig = plt.figure(figsize= (12,8)) #Plot a figure
gs1 = gridspec.GridSpec(2, 1, width_ratios = [3], height_ratios=[1, .04], bottom=.05, top=.95, wspace=.1)
map_proj = ccrs.LambertConformal(central_longitude = -100, central_latitude = 35) #Set projection, central lat/lon
ax = plt.subplot(projection = map_proj)
#ax.set_title('Maximum diameter hail for 2005', fontsize = 22)
ax.add_feature(cfeature.LAND.with_scale('10m')) #Add land
countries_shp = shpreader.natural_earth(resolution='50m',
                                     category='cultural',
                                     name='admin_0_countries')
for country, info in zip(shpreader.Reader(countries_shp).geometries(), 
                             shpreader.Reader(countries_shp).records()):
        if info.attributes['NAME_LONG'] != 'United States':

            ax.add_geometries([country], ccrs.PlateCarree(),
                             facecolor='lightgrey', edgecolor='k', zorder=6)
ax.add_feature(cfeature.NaturalEarthFeature('physical', 'coastline', '50m', edgecolor='k', 
                                                facecolor='None'), zorder=8) 
ax.add_feature(cfeature.BORDERS.with_scale('10m')) #Add state borders
ax.add_feature(cfeature.STATES.with_scale('10m'), facecolor = 'none') #Add US states
ax.add_feature(cfeature.NaturalEarthFeature('physical', 'ocean', '50m', edgecolor='face', 
                                                facecolor='lightsteelblue'), zorder=6)
lakes_shp = shpreader.natural_earth(resolution='50m',
                                     category='physical',
                                     name='lakes')
for lake, info in zip(shpreader.Reader(lakes_shp).geometries(), 
                             shpreader.Reader(lakes_shp).records()):
        name = info.attributes['name']
        if name == 'Lake Superior' or name == 'Lake Michigan' or \
           name == 'Lake Huron' or name == 'Lake Erie' or name == 'Lake Ontario':
            
            ax.add_geometries([lake], ccrs.PlateCarree(),
                             facecolor='lightsteelblue', edgecolor='k', zorder=6)
ax.set_extent([240,287,22,50]) #Set lat/lon boundaries
lrFig = ax.pcolormesh(lons, lats, delta_end8p5_SON, vmin = -0.5, vmax = 0.5, cmap = 'BrBG', transform = ccrs.PlateCarree())
#ax.text(-126, 32, 'SON', fontsize = 60, va='bottom', ha='center', rotation='vertical', transform=ccrs.PlateCarree())
#gls = ax.gridlines(draw_labels=True, dms = True, x_inline=False, y_inline=False, color="black", linestyle="dotted", zorder = 10)
#gls.top_labels=False
#gls.right_labels=False
#gls.xlabel_style = {'size': 18, 'rotation': 0}
#gls.xpadding = 12.0
#gls.ylabel_style = {'size': 18}
plt.title("Δ HAIL_MAX2D (END 8.5 - HIST)", fontsize = 43)
ax1 = plt.subplot(gs1[1, 0])
cb = plt.colorbar(lrFig, cax = ax1, ticks = [-0.5, 0, 0.5], orientation = 'horizontal', extend = 'both')
#cb.set_label('Days', fontsize = 30)
cb.ax.tick_params(labelsize = 30)
plt.subplots_adjust(bottom=0.07)
plt.savefig('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_end_8p5_SON.png')
# Out:
# /anaconda3/envs/pyEAE/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1797: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   result = matplotlib.axes.Axes.pcolormesh(self, *args, **kwargs)
