# %% [markdown]
# # Notebook for plotting seasonal delta HAIL_MAX2D for HIST, mid-FUTR (RCP 4.5, 8.5), and end-FUTR (RCP 4.5, 8.5)

# %% [markdown]
# ### Import necessary libraries

# %%
import numpy as np
import netCDF4 as nc
from netCDF4 import Dataset
import matplotlib.pyplot as plt
import xarray as xr
import matplotlib.gridspec as gridspec
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.io.shapereader as shpreader

# %% [markdown]
# ## Read in HIST max .nc files for DJF, MAM, JJA, and SON (saved to seasonal_mesh_climos/HIST in scratch directory)

# %%
hist_DJF_max_sev = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/HIST/DJF_max_results.nc')
hist_MAM_max_sev = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/HIST/MAM_max_results.nc')
hist_JJA_max_sev = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/HIST/JJA_max_results.nc')
hist_SON_max_sev = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/HIST/SON_max_results.nc')

# %% [markdown]
# ## Read in HIST max .nc files for hail >= 4cm

# %%
hist_DJF_max_4cm = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/HIST/DJF_4cm_results.nc')
hist_MAM_max_4cm = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/HIST/MAM_4cm_results.nc')
hist_JJA_max_4cm = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/HIST/JJA_4cm_results.nc')
hist_SON_max_4cm = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/HIST/SON_4cm_results.nc')

# %% [markdown]
# ## Select HAIL_MAX2D variable to create plottable data array

# %%
hist_DJF_max = hist_DJF_max_sev.HAIL_MAX2D
hist_MAM_max = hist_MAM_max_sev.HAIL_MAX2D
hist_JJA_max = hist_JJA_max_sev.HAIL_MAX2D
hist_SON_max = hist_SON_max_sev.HAIL_MAX2D

#Repeat for 4 cm hail

hist_DJF_max_4cm = hist_DJF_max_4cm.HAIL_MAX2D
hist_MAM_max_4cm = hist_MAM_max_4cm.HAIL_MAX2D
hist_JJA_max_4cm = hist_JJA_max_4cm.HAIL_MAX2D
hist_SON_max_4cm = hist_SON_max_4cm.HAIL_MAX2D

# %% [markdown]
# ## Read in seasonal max files for mid, end-FUTR RCP 4.5, 8.5 (saved to seasonal_resamples in scratch directory)

# %%
mid_4p5_seasonal_max = xr.open_dataset('/home/scratch/jgoodin/seasonal_resamples/mid-century_4p5_seasonal_max_resample.nc')
mid_8p5_seasonal_max = xr.open_dataset('/home/scratch/jgoodin/seasonal_resamples/mid-century_8p5_seasonal_max_resample.nc')
end_4p5_seasonal_max = xr.open_dataset('/home/scratch/jgoodin/seasonal_resamples/end-century_4p5_seasonal_max_resample.nc')
end_8p5_seasonal_max = xr.open_dataset('/home/scratch/jgoodin/seasonal_resamples/end-century_8p5_seasonal_max_resample.nc')

# %% [markdown]
# ## Select HAIL_MAX2D values that meet severe citeria (1 in [2.54 cm])

# %%
mid_4p5_seasonal_max_sev = mid_4p5_seasonal_max.where(mid_4p5_seasonal_max >= 1)
mid_8p5_seasonal_max_sev = mid_8p5_seasonal_max.where(mid_8p5_seasonal_max >= 1)
end_4p5_seasonal_max_sev = end_4p5_seasonal_max.where(end_4p5_seasonal_max >= 1)
end_8p5_seasonal_max_sev = end_8p5_seasonal_max.where(end_8p5_seasonal_max >= 1)

#Repeat for 4 cm (1.57 in) hail

mid_4p5_seasonal_max_4cm = mid_4p5_seasonal_max.where(mid_4p5_seasonal_max >= 1.5748)
mid_8p5_seasonal_max_4cm = mid_8p5_seasonal_max.where(mid_8p5_seasonal_max >= 1.5748)
end_4p5_seasonal_max_4cm = end_4p5_seasonal_max.where(end_4p5_seasonal_max >= 1.5748)
end_8p5_seasonal_max_4cm = end_8p5_seasonal_max.where(end_8p5_seasonal_max >= 1.5748)

# %% [markdown]
# ## Select by season for each FUTR file and save results to netcdf

# %% [markdown]
# ### Select by season and hail size for mid-FUTR RCP 4.5

# %%
#mid4p5_SON_sev_max = mid_4p5_seasonal_max_sev.sel(season = 'SON').HAIL_MAX2D
#mid4p5_SON_4cm_max = mid_4p5_seasonal_max_4cm.sel(season = 'SON').HAIL_MAX2D

# %% [markdown]
# ### Save results to netcdf (saved to seasonal_mesh_climos/mid-FUTR directory in scratch)

# %%
#mid4p5_SON_sev_max.to_netcdf('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid4p5_SON_seasonal_sev_max.nc')
#mid4p5_SON_4cm_max.to_netcdf('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid4p5_SON_seasonal_4cm_max.nc')

# %% [markdown]
# ## Repeat process for mid-FUTR RCP 8.5

# %%
#mid8p5_DJF_sev_max = mid_8p5_seasonal_max_sev.sel(season = 'SON').HAIL_MAX2D
#mid8p5_DJF_4cm_max = mid_8p5_seasonal_max_4cm.sel(season = 'SON').HAIL_MAX2D

# %% [markdown]
# ### Save results to netcdf (saved to seasonal_mesh_climos/mid-FUTR directory in scratch)

# %%
#mid8p5_DJF_sev_max.to_netcdf('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid8p5_SON_seasonal_sev_max.nc')
#mid8p5_DJF_4cm_max.to_netcdf('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid8p5_SON_seasonal_4cm_max.nc')

# %% [markdown]
# ## Repeat for end-FUTR RCP 4.5

# %%
#end4p5_SON_sev_max = end_4p5_seasonal_max_sev.sel(season = 'SON').HAIL_MAX2D
#end4p5_SON_sev_4cm_max = end_4p5_seasonal_max_4cm.sel(season = 'SON').HAIL_MAX2D

# %% [markdown]
# ### Save results to netcdf (saved to seasonal_mesh_climos/end-FUTR directory in scratch)

# %%
#end4p5_SON_sev_max.to_netcdf('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end4p5_SON_seasonal_sev_max.nc')
#end4p5_SON_sev_4cm_max.to_netcdf('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end4p5_SON_seasonal_4cm_max.nc')

# %% [markdown]
# ## Repeat for end-FUTR RCP 8.5

# %%
#end8p5_SON_sev_max = end_8p5_seasonal_max_sev.sel(season = 'SON').HAIL_MAX2D
#end8p5_SON_4cm_max = end_8p5_seasonal_max_4cm.sel(season = 'SON').HAIL_MAX2D

# %% [markdown]
# ### Save results to netcdf (saved to seasonal_mesh_climos/end-FUTR directory in scratch)

# %%
#end8p5_SON_sev_max.to_netcdf('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end8p5_SON_seasonal_sev_max.nc')
#end8p5_SON_4cm_max.to_netcdf('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end8p5_SON_seasonal_4cm_max.nc')

# %% [markdown]
# ## Assign each seasonal max [1 in] file created above to a variable (DJF, MAM, JJA, SON)

# %%
mid_4p5_DJF_sev = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid4p5_DJF_seasonal_sev_max.nc')
mid_4p5_MAM_sev = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid4p5_MAM_seasonal_sev_max.nc')
mid_4p5_JJA_sev = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid4p5_JJA_seasonal_sev_max.nc')
mid_4p5_SON_sev = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid4p5_SON_seasonal_sev_max.nc')

#Repeat for mid-FUTR RCP 8.5

mid_8p5_DJF_sev = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid8p5_DJF_seasonal_sev_max.nc')
mid_8p5_MAM_sev = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid8p5_MAM_seasonal_sev_max.nc')
mid_8p5_JJA_sev = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid8p5_JJA_seasonal_sev_max.nc')
mid_8p5_SON_sev = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid8p5_SON_seasonal_sev_max.nc')

# %% [markdown]
# ### Repeat for end-FUTR [1 in]

# %%
end_4p5_DJF_sev = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end4p5_DJF_seasonal_sev_max.nc')
end_4p5_MAM_sev = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end4p5_MAM_seasonal_sev_max.nc')
end_4p5_JJA_sev = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end4p5_JJA_seasonal_sev_max.nc')
end_4p5_SON_sev = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end4p5_SON_seasonal_sev_max.nc')

#Repeat for end-FUTR RCP 8.5

end_8p5_DJF_sev = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end8p5_DJF_seasonal_sev_max.nc')
end_8p5_MAM_sev = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end8p5_MAM_seasonal_sev_max.nc')
end_8p5_JJA_sev = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end8p5_JJA_seasonal_sev_max.nc')
end_8p5_SON_sev = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end8p5_SON_seasonal_sev_max.nc')

# %% [markdown]
# ## Repeat above process for hail ≥ 4cm

# %%
mid_4p5_DJF_4cm = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid4p5_DJF_seasonal_4cm_max.nc')
mid_4p5_MAM_4cm = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid4p5_MAM_seasonal_4cm_max.nc')
mid_4p5_JJA_4cm = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid4p5_JJA_seasonal_4cm_max.nc')
mid_4p5_SON_4cm = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid4p5_SON_seasonal_4cm_max.nc')

#Repeat for mid-FUTR RCP 8.5

mid_8p5_DJF_4cm = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid8p5_DJF_seasonal_4cm_max.nc')
mid_8p5_MAM_4cm = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid8p5_MAM_seasonal_4cm_max.nc')
mid_8p5_JJA_4cm = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid8p5_JJA_seasonal_4cm_max.nc')
mid_8p5_SON_4cm = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/mid-FUTR/mid8p5_SON_seasonal_4cm_max.nc')

# %% [markdown]
# ### Repeat for end-FUTR [≥ 4cm]

# %%
end_4p5_DJF_4cm = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end4p5_DJF_seasonal_4cm_max.nc')
end_4p5_MAM_4cm = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end4p5_MAM_seasonal_4cm_max.nc')
end_4p5_JJA_4cm = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end4p5_JJA_seasonal_4cm_max.nc')
end_4p5_SON_4cm = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end4p5_SON_seasonal_4cm_max.nc')

#Repeat for end-FUTR RCP 8.5

end_8p5_DJF_4cm = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end8p5_DJF_seasonal_4cm_max.nc')
end_8p5_MAM_4cm = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end8p5_MAM_seasonal_4cm_max.nc')
end_8p5_JJA_4cm = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end8p5_JJA_seasonal_4cm_max.nc')
end_8p5_SON_4cm = xr.open_dataset('/home/scratch/jgoodin/seasonal_mesh_climos/end-FUTR/end8p5_SON_seasonal_4cm_max.nc')

# %% [markdown]
# ## Select values of HAIL_MAX2D to create a plottable data array ]sev]

# %%
mid_4p5_DJF_sev = mid_4p5_DJF_sev.HAIL_MAX2D
mid_4p5_MAM_sev = mid_4p5_MAM_sev.HAIL_MAX2D
mid_4p5_JJA_sev = mid_4p5_JJA_sev.HAIL_MAX2D
mid_4p5_SON_sev = mid_4p5_SON_sev.HAIL_MAX2D

mid_8p5_DJF_sev = mid_8p5_DJF_sev.HAIL_MAX2D
mid_8p5_MAM_sev = mid_8p5_MAM_sev.HAIL_MAX2D
mid_8p5_JJA_sev = mid_8p5_JJA_sev.HAIL_MAX2D
mid_8p5_SON_sev = mid_8p5_SON_sev.HAIL_MAX2D

#Repeat for end-FUTR

end_4p5_DJF_sev = end_4p5_DJF_sev.HAIL_MAX2D
end_4p5_MAM_sev = end_4p5_MAM_sev.HAIL_MAX2D
end_4p5_JJA_sev = end_4p5_JJA_sev.HAIL_MAX2D
end_4p5_SON_sev = end_4p5_SON_sev.HAIL_MAX2D

end_8p5_DJF_sev = end_8p5_DJF_sev.HAIL_MAX2D
end_8p5_MAM_sev = end_8p5_MAM_sev.HAIL_MAX2D
end_8p5_JJA_sev = end_8p5_JJA_sev.HAIL_MAX2D
end_8p5_SON_sev = end_8p5_SON_sev.HAIL_MAX2D

# %% [markdown]
# ## Repeat for ≥ 4cm

# %%
mid_4p5_DJF_4cm = mid_4p5_DJF_4cm.HAIL_MAX2D
mid_4p5_MAM_4cm = mid_4p5_MAM_4cm.HAIL_MAX2D
mid_4p5_JJA_4cm = mid_4p5_JJA_4cm.HAIL_MAX2D
mid_4p5_SON_4cm = mid_4p5_SON_4cm.HAIL_MAX2D

mid_8p5_DJF_4cm = mid_8p5_DJF_4cm.HAIL_MAX2D
mid_8p5_MAM_4cm = mid_8p5_MAM_4cm.HAIL_MAX2D
mid_8p5_JJA_4cm = mid_8p5_JJA_4cm.HAIL_MAX2D
mid_8p5_SON_4cm = mid_8p5_SON_4cm.HAIL_MAX2D

#Repeat for end-FUTR

end_4p5_DJF_4cm = end_4p5_DJF_4cm.HAIL_MAX2D
end_4p5_MAM_4cm = end_4p5_MAM_4cm.HAIL_MAX2D
end_4p5_JJA_4cm = end_4p5_JJA_4cm.HAIL_MAX2D
end_4p5_SON_4cm = end_4p5_SON_4cm.HAIL_MAX2D

end_8p5_DJF_4cm = end_8p5_DJF_4cm.HAIL_MAX2D
end_8p5_MAM_4cm = end_8p5_MAM_4cm.HAIL_MAX2D
end_8p5_JJA_4cm = end_8p5_JJA_4cm.HAIL_MAX2D
end_8p5_SON_4cm = end_8p5_SON_4cm.HAIL_MAX2D

# %% [markdown]
# # Find deltas by subtracting HIST from FUTR (start with delta hist mid-FUTR RCP 4.5, 8.5)

# %%
delta_mid4p5_DJF_sev = mid_4p5_DJF_sev - hist_DJF_max
delta_mid4p5_MAM_sev = mid_4p5_MAM_sev - hist_MAM_max 
delta_mid4p5_JJA_sev = mid_4p5_JJA_sev - hist_JJA_max 
delta_mid4p5_SON_sev = mid_4p5_SON_sev - hist_SON_max 

#Repeat for mid-FUTR RCP 8.5                  # **These are plotting variables**

delta_mid8p5_DJF_sev = mid_8p5_DJF_sev - hist_DJF_max
delta_mid8p5_MAM_sev = mid_8p5_MAM_sev - hist_MAM_max 
delta_mid8p5_JJA_sev = mid_8p5_JJA_sev - hist_JJA_max 
delta_mid8p5_SON_sev = mid_8p5_SON_sev - hist_SON_max

# %% [markdown]
# ## Repeat for ≥ 4 cm

# %%
delta_mid4p5_DJF_4cm = mid_4p5_DJF_4cm - hist_DJF_max_4cm
delta_mid4p5_MAM_4cm = mid_4p5_MAM_4cm - hist_MAM_max_4cm 
delta_mid4p5_JJA_4cm = mid_4p5_JJA_4cm - hist_JJA_max_4cm 
delta_mid4p5_SON_4cm = mid_4p5_SON_4cm - hist_SON_max_4cm 

#Repeat for mid-FUTR RCP 8.5                  # **These are plotting variables**

delta_mid8p5_DJF_4cm = mid_8p5_DJF_4cm - hist_DJF_max_4cm
delta_mid8p5_MAM_4cm = mid_8p5_MAM_4cm - hist_MAM_max_4cm 
delta_mid8p5_JJA_4cm = mid_8p5_JJA_4cm - hist_JJA_max_4cm 
delta_mid8p5_SON_4cm = mid_8p5_SON_4cm - hist_SON_max_4cm

# %% [markdown]
# # Find deltas for end-FUTR RCP 4.5, 8.5

# %%
delta_end4p5_DJF_sev = end_4p5_DJF_sev - hist_DJF_max 
delta_end4p5_MAM_sev = end_4p5_MAM_sev - hist_MAM_max 
delta_end4p5_JJA_sev = end_4p5_JJA_sev - hist_JJA_max 
delta_end4p5_SON_sev = end_4p5_SON_sev - hist_SON_max 

#Repeat for mid-FUTR RCP 8.5                   # **These are plotting variables**

delta_end8p5_DJF_sev = end_8p5_DJF_sev - hist_DJF_max 
delta_end8p5_MAM_sev = end_8p5_MAM_sev - hist_MAM_max 
delta_end8p5_JJA_sev = end_8p5_JJA_sev - hist_JJA_max 
delta_end8p5_SON_sev = end_8p5_SON_sev - hist_SON_max

# %% [markdown]
# ## Repeat for ≥ 4 cm

# %%
delta_end4p5_DJF_4cm = mid_4p5_DJF_4cm - hist_DJF_max_4cm
delta_end4p5_MAM_4cm = mid_4p5_MAM_4cm - hist_MAM_max_4cm 
delta_end4p5_JJA_4cm = mid_4p5_JJA_4cm - hist_JJA_max_4cm 
delta_end4p5_SON_4cm = mid_4p5_SON_4cm - hist_SON_max_4cm 

#Repeat for mid-FUTR RCP 8.5                  # **These are plotting variables**

delta_end8p5_DJF_4cm = mid_8p5_DJF_4cm - hist_DJF_max_4cm
delta_end8p5_MAM_4cm = mid_8p5_MAM_4cm - hist_MAM_max_4cm 
delta_end8p5_JJA_4cm = mid_8p5_JJA_4cm - hist_JJA_max_4cm 
delta_end8p5_SON_4cm = mid_8p5_SON_4cm - hist_SON_max_4cm

# %% [markdown]
# ### Import netcdf file containing lat/lon coords for WRF files

# %%
coords = xr.open_dataset('lat_lon.nc') #Open .nc file containing WRF lat/lon coords

# %% [markdown]
# ### Assign lat/lon coords from file to variables

# %%
lats = coords.CLAT.values[0, :, :]
lons = coords.CLONG.values[0, :, :]

# %% [markdown]
# ## Plot deltas on map of CONUS

# %%
fig = plt.figure(figsize= (12,8)) #Plot a figure
gs1 = gridspec.GridSpec(2, 1, width_ratios = [3], height_ratios=[1, .04], bottom=.05, top=.95, wspace=.1)
map_proj = ccrs.LambertConformal(central_longitude = -100, central_latitude = 35) #Set projection, central lat/lon
ax = plt.subplot(projection = map_proj)
#ax.set_title('Maximum diameter hail for 2005', fontsize = 22)
ax.add_feature(cfeature.LAND.with_scale('10m')) #Add land
countries_shp = shpreader.natural_earth(resolution='50m',
                                     category='cultural',
                                     name='admin_0_countries')
for country, info in zip(shpreader.Reader(countries_shp).geometries(), 
                             shpreader.Reader(countries_shp).records()):
        if info.attributes['NAME_LONG'] != 'United States':

            ax.add_geometries([country], ccrs.PlateCarree(),
                             facecolor='lightgrey', edgecolor='k', zorder=6)
ax.add_feature(cfeature.NaturalEarthFeature('physical', 'coastline', '50m', edgecolor='k', 
                                                facecolor='None'), zorder=8) 
ax.add_feature(cfeature.BORDERS.with_scale('10m')) #Add state borders
ax.add_feature(cfeature.STATES.with_scale('10m'), facecolor = 'none') #Add US states
ax.add_feature(cfeature.NaturalEarthFeature('physical', 'ocean', '50m', edgecolor='face', 
                                                facecolor='lightsteelblue'), zorder=6)
lakes_shp = shpreader.natural_earth(resolution='50m',
                                     category='physical',
                                     name='lakes')
for lake, info in zip(shpreader.Reader(lakes_shp).geometries(), 
                             shpreader.Reader(lakes_shp).records()):
        name = info.attributes['name']
        if name == 'Lake Superior' or name == 'Lake Michigan' or \
           name == 'Lake Huron' or name == 'Lake Erie' or name == 'Lake Ontario':
            
            ax.add_geometries([lake], ccrs.PlateCarree(),
                             facecolor='lightsteelblue', edgecolor='k', zorder=6)
ax.set_extent([240,287,22,50]) #Set lat/lon boundaries
lrFig = ax.pcolormesh(lons, lats, delta_end8p5_SON_4cm, vmin = -0.4, vmax = 0.4, cmap = 'seismic', transform = ccrs.PlateCarree())
#ax.text(-126, 32, 'SON', fontsize = 64, va='bottom', ha='center', rotation='vertical', transform=ccrs.PlateCarree())
#gls = ax.gridlines(draw_labels=True, dms = True, x_inline=False, y_inline=False, color="black", linestyle="dotted", zorder = 10)
#gls.top_labels=False
#gls.right_labels=False
#gls.xlabel_style = {'size': 18, 'rotation': 0}
#gls.xpadding = 12.0
#gls.ylabel_style = {'size': 18}
plt.title("Δ HAIL ≥ 1.57 in (END 8.5 - HIST)", fontsize = 48)
ax1 = plt.subplot(gs1[1, 0])
cb = plt.colorbar(lrFig, cax = ax1, ticks = [-0.4, 0, 0.4], orientation = 'horizontal', extend = 'both')
#cb.set_label('Days', fontsize = 30)
cb.ax.tick_params(labelsize = 32)
plt.subplots_adjust(bottom=0.07)
plt.savefig('/home/scratch/jgoodin/seasonal_mesh_climos/deltas/delta_end_8p5_SON_4cm.png')
# Out:
# /anaconda3/envs/pyEAE/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1797: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   result = matplotlib.axes.Axes.pcolormesh(self, *args, **kwargs)
